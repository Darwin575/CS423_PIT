# %% [markdown]
# # Lariosa, Gerald Darwin D.

# %% [markdown]
# *February 10, 2025*

# %% [markdown]
# ## Import Libraries

# %%
import urllib.request
from bs4 import BeautifulSoup
import nltk
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %% [markdown]
# ## Scrape Website Data

# %%
url = "https://www.theguardian.com/international"
response = urllib.request.urlopen(url)
html = response.read()
soup = BeautifulSoup(html, 'html.parser')
text = soup.get_text()

# %%
print(text)
# Out:
# Latest news, sport and opinion from the Guardian
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to main contentSkip to navigationPrint subscriptionsSearch jobs Sign inIntInternational editionUK editionUS editionAustralia editionEurope editionThe Guardian - Back to homeThe GuardianNewsOpinionSportCultureLifestyleShow moreHide expanded menuNewsView all NewsWorld newsUS politicsUK newsClimate crisisMiddle EastUkraineEnvironmentScienceGlobal developmentFootballTechBusinessObituariesOpinionView all OpinionThe Guardian viewColumnistsCartoonsOpinion videosLettersSportView all SportFootballCricketRugby unionTennisCyclingF1GolfUS sportsCultureView all CultureBooksMusicTV & radioArt & designFilmGamesClassicalStageLifestyleView all LifestyleFashionFoodRecipesLove & sexHealth & fitnessHome & gardenWomenMenFamilyTravelMoneySearch input google-search SearchSupport usPrint subscriptionsSearch jobsHolidaysDigital ArchiveGuardian LicensingAbout UsThe Guardian appVideoPodcastsPicturesNewslettersToday's paperInside the GuardianThe ObserverGuardian WeeklyCrosswordsWordiplyCorrectionsSearch input google-search SearchSearch jobsHolidaysDigital ArchiveGuardian LicensingAbout UsWorldUS politicsUKClimate crisisMiddle EastUkraineEnvironmentScienceGlobal developmentFootballTechBusinessObituariesHeadlinesTarrifsTrump to announce 25% aluminum and steel tariffs as China’s levies against US come into effectUS president accused of ‘shifting goalposts’ by premier of Ontario for adding further tariffs on top of existing metal duties, as China’s fossil fuel levies comes into force43m agoBusiness liveTrump tariffs: Gold hits record high as new steel and aluminium tariff announcement rattles marketsInternational tradeGold hits record high as Trump announces tariffs on steel and aluminiumUS defenceTrump predicts ‘billions’ of dollars of Pentagon fraud in Fox News interviewMiddle East crisis liveReturning Palestinians ‘shocked’ by ‘complete scale of destruction’ of northern Gaza26m agoSuper Bowl LIXMerciless Philadelphia Eagles dismantle Kansas City Chiefs to win Super Bowl4h ago…… commentsGallerySuper Bowl LIX in picturesScienceEuclid telescope captures Einstein ring revealing warping of space53m agoFranceFrance braces for trial of surgeon accused of sexually abusing hundreds of children4h agoIndiaMore than 1,100 dead sea turtles washed up along southern India’s coastline4h agoEd SheeranPolice in India stop Ed Sheeran busking on street before concert36m agoUkraine war liveZelenskyy ready for talks if given ‘an understanding that US and Europe will not abandon us’21m agoPacificNew Zealand raises ‘concern’ as Cook Islands prepares to sign China deal 5h agoAustralia Sewer fatberg of ‘grease and rags’ forces Bryan Adams to cancel Perth concert10h agoNews in focusHideSyria‘Finally this is justice’: the Assad torture survivors who guard their former jail4h agoSouth AfricaBo-Kaap: the candy-coloured corner of Cape Town facing tourism v heritage dilemmaSome locals in picturesque district of Bo-Kaap are fed up with influx of visitors, and worry about impact of gentrification4h agoEthiopiaLast throw of the boule for Addis Ababa’s historic pétanque club as developers turn city into hi-tech hubIn the heart of the Ethiopian capital is a relic of the French-built railway but the government’s grandiose redevelopment plans threaten this friendly club53m agoSpotlightHideReviewKendrick Lamar’s Super Bowl
�billions’ of dollars of Pentagon fraud in Fox News interview‘They will collide eventually’: how long will the Trump-Musk relationship survive?Donald Trump is remaking the world. But he really won’t like the resultAsil Nadir, Polly Peck tycoon turned fugitive, dies aged 83France braces for trial of surgeon accused of sexually abusing hundreds of childrenExplore more on these topicsDonald TrumpMiddle East and north AfricaEuropeUS politicsIsraelWorldUS politicsUKClimate crisisMiddle EastUkraineEnvironmentScienceGlobal developmentFootballTechBusinessObituariesNewsOpinionSportCultureLifestyleOriginal rep ...

# %% [markdown]
# ##  Load Stopwords

# %%
with open("stop_words.txt", "r") as f:
    stop_words = set(f.read().split())

# %% [markdown]
# ## Tokenize and Count Stopwords

# %%
tokens = [token for token in text.split()]
stopword_count = [word for word in tokens if word.lower() in stop_words]

print(f"Total Stopwords Found: {len(stopword_count)}")
print("Stopwords List:", stopword_count)
# Out:
# Total Stopwords Found: 630
# Stopwords List: ['and', 'from', 'the', 'to', 'to', 'to', 'all', 'all', 'all', 'all', 'all', 'the', 'to', 'and', 'as', 'against', 'come', 'into', 'of', 'by', 'of', 'for', 'further', 'on', 'of', 'as', 'into', 'as', 'and', 'as', 'on', 'and', 'of', 'of', 'in', 'by', 'of', 'of', 'to', 'in', 'of', 'for', 'of', 'of', 'of', 'than', 'up', 'in', 'on', 'before', 'for', 'if', 'that', 'and', 'not', 'as', 'to', 'of', 'and', 'to', 'in', 'this', 'is', 'the', 'who', 'their', 'the', 'of', 'in', 'of', 'are', 'up', 'with', 'of', 'and', 'about', 'of', 'of', 'the', 'for', 'as', 'into', 'the', 'of', 'the', 'is', 'a', 'of', 'the', 'but', 'the', 'this', 'over', 'for', 'over', 'more', 'in', 'an', 'the', 'to', 'his', 'was', 'with', 'how', 'and', 'into', 'the', 'who', 'the', 'in', 'their', 'to', 'of', 'at', 'a', 'in', 'The', 'as', 'as', 'how', 'to', 'all', 'under', 'the', 'of', 'is', 'the', 'he', 'to', 'why', 'about', 'his', 'and', 'his', 'was', 'But', 'the', 'Now', 'are', 'that', 'and', 'the', 'who', 'it', 'it', 'that', 'it', 'that', 'you', 'should', 'a', 'and', 'a', 'the', 'with', 'in', 'the', 'of', 'of', 'the', 'who', 'a', 'and', 'the', 'to', 'is', 'the', 'But', 'he', 'the', 'an', 'his', 'are', 'more', 'His', 'be', 'not', 'to', 'to', 'and', 'she', 'to', 'to', 'Why', 'the', 'the', 'of', 'no', 'of', 'not', 'on', 'and', 'a', 'there', 'are', 'to', 'with', 'than', 'and', 'with', 'why', 'I', 'the', 'from', 'the', 'from', 'his', 'and', 'at', 'his', 'after', 'again', 'but', 'for', 'out', 'of', 'was', 'He', 'and', 'with', 'to', 'a', 'after', 'off', 'out', 'of', 'up', 'and', 'get', 'our', 'to', 'your', 'has', 'as', 'come', 'and', 'up', 'for', 'our', 'through', 'to', 'with', 'to', 'the', 'as', 'to', 'over', 'on', 'after', 'in', 'of', 'after', 'in', 'off', 'with', 'the', 'and', 'most', 'to', 'as', 'after', 'from', 'to', 'the', 'did', 'not', 'of', 'and', 'the', 'to', 'on', 'after', 'in', 'while', 'for', 'be', 'by', 'as', 'to', 'for', 'to', 'the', 'in', 'from', 'in', 'as', 'of', 'in', 'while', 'in', 'of', 'of', 'for', 'and', 'of', 'of', 'Get', 'the', 'and', 'was', 'for', 'his', 'of', 'and', 'of', 'the', 'on', 'of', 'the', 'by', 'a', 'of', 'in', 'my', 'most', 'of', 'the', 'up', 'for', 'on', 'and', 'and', 'the', 'is', 'a', 'of', 'for', 'for', 'The', 'to', 'a', 'you', 'can', 'a', 'you', 'more', 'to', 'with', 'it', 'and', 'for', 'their', 'and', 'the', 'to', 'a', 'in', 'for', 'with', 'and', 'and', 'and', 'my', 'was', 'on', 'the', 'it', 'was', 'and', 'Why', 'I', 'at', 'myself', 'on', 'do', 'I', 'when', 'is', 'at', 'me', 'my', 'and', 'when', 'not', 'my', 'you', 'been', 'by', 'the', 'on', 'you', 'have', 'a', 'you', 'how', 'you', 'are', 'with', 'the', 'of', 'your', 'your', 'of', 'the', 'of', 'being', 'as', 'a', 'more', 'and', 'to', 'our', 'on', 'for', 'in', 'on', 'for', 'of', 'at', 'where', 'then', 'in', 'before', 'of', 'in', 'before', 'of', 'and', 'my', 'to', 'do', 'but', 'of', 'in', 'the', 'who', 'a', 'in', 'a', 'of', 'to', 'you', 'about', 'the', 'of', 'of', 'a', 'was', 'by', 'Now', 'a', 'with', 'its', 'to', 'my', 'is', 'this', 'in', 'be', 'to', 'it', 'in', 'have', 'as', 'against', 'on', 'after', 'for', 'our', 'before', 'his', 'on', 'and', 'we', 'the', 'not', 'to', 'You', 'have', 'more', 'and', 'to', 'the', 'and', 'your', 'with', 'your', 'me', 'my', 'how', 'was', 'in', 'the', 'in', 'a', 'on', 'and', 'the', 'who', 'on', 'and', 'and', 'on', 'to', 'the', 'of', 'against', 'after', 'in', 'as', 'up', 'in', 'and', 'for', 'as', 'with', 'with', 'as', 'can', 'in', 'for', 'their', 'on', 'and', 'a', 'in', 'the', 'has', 'in', 'that', 'in', 'the', 'the', 'in', 'the', 'with', 'a', 'from', 'to', 'in', 'and', 'in', 'the', 'the', 'in', 'the', 'of', 'the', 'to', 'the', 'in', 'in', 'and', 'at', 'the', 'on', 'the', 'the', 'of', 'the', 'are', 'for', 'of', 'of', 'of', 'as', 'to', 'Is', 'it', 'to', 'the', 'on', 'the', 'of', 'to', 'in', 'to', 'this', 'is', 'the', 'who', 'their', 'of', 'for', 'and', 'by', 'of', 'of', 'are', 'with', 'over', 'for', 'is', 'the', 'he', 'to', 'why', 'about', 'his', 'of ...

# %%
freq_dis_nltk = nltk.FreqDist(tokens)
freq_dis_nltk
# Out:
# FreqDist({'the': 69, 'of': 67, 'and': 49, 'to': 47, 'in': 41, 'for': 27, 'on': 22, 'a': 21, 'as': 19, 'with': 18, ...})

# %% [markdown]
# ## Clean Tokens and Generate Word Cloud

# %%
clean_tokens = [word.lower() for word in tokens if word.lower() not in stop_words and word.isalpha()]
freq_dis_nltk = nltk.FreqDist(clean_tokens)

wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(freq_dis_nltk)

# %% [markdown]
# ## Visualize Frequency Distribution

# %%
plt.figure(figsize=(12, 6))
freq_dis_nltk.plot(30, cumulative=False)
plt.show()

# %% [markdown]
# ##  Display Word Cloud

# %%
# Step 6: Display Word Cloud with Enhanced Aesthetics
wordcloud = WordCloud(
    width=800, 
    height=400, 
    background_color='black',  
    colormap='viridis',  
    contour_color='white', 
    contour_width=2
).generate_from_frequencies(freq_dis_nltk)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
